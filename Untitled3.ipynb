# %%
def get_cars_catalog():
    cars_catalog = []

    cars = [
        {("Mercedes-Benz", "S-Class"): {
            "price": 2000,
            "двигатель": 3.0,
            "привод": "задний",
            "разгон до 100": 6.2,
            "выпуск": "2018",
            "страна": "Германия"}
        },
                                        
        {("BMW", "5 Series"): {"price": 1500,
                            "двигатель": 2.0,
                            "привод": "задний",
                            "разгон до 100": 7.0,
                            "выпуск": "2019",
                            "страна": "Германия"}},
                            
        {("Audi", "A6"): {"price": 1700,
                        "двигатель": 2.0,
                        "привод": "полный",
                        "разгон до 100": 7.5,
                        "выпуск": "2020",
                        "страна": "Германия"}},
                        
        {("Toyota", "Camry"): {"price": 1200,
                            "двигатель": 2.5,
                            "привод": "передний",
                            "разгон до 100": 8.5,
                            "выпуск": "2021",
                            "страна": "Япония"}},
                            
        {("Honda", "Accord"): {"price": 1100,
                            "двигатель": 1.5,
                            "привод": "передний",
                            "разгон до 100": 8.0,
                            "выпуск": "2022",
                            "страна": "Япония"}},
                            
        {("Ford", "Mustang"): {"price": 2500,
                            "двигатель": 5.0,
                            "привод": "задний",
                            "разгон до 100": 4.3,
                            "выпуск": "2020",
                            "страна": "США"}},
                            
        {("Volkswagen", "Passat"): {"price": 900,
                                    "двигатель": 1.8,
                                    "привод": "передний",
                                    "разгон до 100": 8.6,
                                    "выпуск": "2019",
                                    "страна": "Германия"}},
                                    
        {("Hyundai", "Sonata"): {"price": 800,
                                "двигатель": 2.0,
                                "привод": "передний",
                                "разгон до 100": 8.8,
                                "выпуск": "2021",
                                "страна": "Южная Корея"}},
                                
        {("Kia", "K5"): {"price": 850,
                        "двигатель": 1.6,
                        "привод": "передний",
                        "разгон до 100": 8.2,
                        "выпуск": "2022",
                        "страна": "Южная Корея"}},
                        
        {("Lexus", "ES"): {"price": 1800,
                        "двигатель": 2.5,
                        "привод": "передний",
                        "разгон до 100": 8.6,
                        "выпуск": "2020",
                        "страна": "Япония"}}
    ]

    cars_catalog.extend(cars)

    for car in cars_catalog:
        for key in car:
            car[key]["рассрочка"] = True


    return cars_catalog


def prepare(catalog, param, kriteriy):
    match_cars = []
    
    for car in catalog:
        for car_key, characteristics in car.items():
            if param in characteristics and characteristics[param] == kriteriy:
                brand, model = car_key
                match_cars.append(f"Бренд - {brand}; Модель - {model}")
    
    return match_cars


def main():
    param = 'выпуск'
    kriteriy = "2019"
    cars_catalog = get_cars_catalog()
    match_cars = prepare(cars_catalog, param, kriteriy)
    for car in match_cars:
        print(car)



if __name__ == "__main__":
    main()
# Out:
# [('BMW', '5 Series'), ('Volkswagen', 'Passat')]
